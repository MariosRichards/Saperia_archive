# %%
# Converting "Newspeak House Unmailing List.xlsx" to a database

# "A repository of open channels containing people working on political and civic technology."

# Initial cleaning:
# * download the four individual sheets in the Google Sheet
# * remove the left-most column (present for construction notes)
# * trim any excess rows at the top

# use of colours
    # purple and green - don't know what they mean!

# Groups
# Membership required
# Newsletters
    # "need to expand" snipped off leftmost column "Name":"Awesome newsletters"
    # a load of blank rows in middle
# working
    # quite messy
    # a lot of stuff remaining in leftmost column
    # copy of header column appears pasted into a row


# URL	Name	Type	Self-Description	Purpose	Some Associated Projects	District	Country	Language	Topic	Topic	Topic	Topic	Topic	Notes

# %%
## Sanitation

# URL -> check they all work (at least, check that they function *now*!)
   # at the moment, this appears to be the "Primary Field" (unique key)
    # which is a problem, since it's not unique!
# Name -> should be unique (some are not)
    # we have organisations with different entries fro slackchat and github
# Type -> we need a fixed set of types
# Self-Description -> Text
# Purpose -> Text
# Some Associated Projects -> another table
# District -> **very patchy, no clear ontology (I'm sure this already exists)
# Country -> **ditto, no need to remake the wheel (lot of variants on 'global')
# Language -> **English (again, don't remake wheel)
# Topic1 ... Topic5 -> need a finite list
    # multiple select would look good if I can figure out
    # how to import directly or convert? ("gfgf,fgfg,fgf" maybe?)
    # apparently so
# Notes -> emails, links ... and some stuff that looked like Types
    # Network/In Person Event
# Sheet -> higher level type of ... Type

# Reorder columns!
# ['URL', 'Name', 'Type', 'Self-Description', 'Purpose',
#        'Some Associated Projects', 'District', 'Country', 'Language', 'Topic1',
#        'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Notes', 'Sheet']

['URL', 'Name',
 'Sheet', 'Type',
 'Self-Description', 'Purpose',
 'Notes',
 'Topics',
 'Projects',
 'Language', 'Country', 'District' ]

# Extra tables?
# District, Country
    # sure this already exist as a ready made (pair of) tables
# Topics
# Sheet, Type
    # should probably also be a set of paired tables
# Out:
# ['URL',
#  'Name',
#  'Sheet',
#  'Type',
#  'Self-Description',
#  'Purpose',
#  'Notes',
#  'Topics',
#  'Projects',
#  'Language',
#  'Country',
#  'District']

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import pickle, os

# %%
SA_data_folder = "../Saperia_archive_data/" # Saperia_archive\Saperia_archive_data
SA_code_folder = "../Saperia_archive_code/"

# %%
SA_Groups         = pd.read_csv(SA_data_folder+"Newspeak House Unmailing List - Groups - trimmed.csv")
print("SA_Groups " , SA_Groups.shape)
SA_Membership_req = pd.read_csv(SA_data_folder+"Newspeak House Unmailing List - Membership required - trimmed.csv")
print("SA_Membership_req " , SA_Membership_req.shape)
SA_Newsletters    = pd.read_csv(SA_data_folder+"Newspeak House Unmailing List - Newsletters - trimmed.csv")
print("SA_Newsletters " , SA_Newsletters.shape)
# SA_working = pd.read_csv(SA_data_folder+"Newspeak House Unmailing List - working - trimmed.csv")
# Out:
# SA_Groups  (120, 15)
# SA_Membership_req  (15, 15)
# SA_Newsletters  (10, 15)

# %%
all(SA_Groups.columns == SA_Membership_req.columns) and all(SA_Membership_req.columns == SA_Newsletters.columns)
# column header identical
# Out:
# True

# %%
SA_Groups.columns
# Out:
# Index(['URL', 'Name', 'Type', 'Self-Description', 'Purpose',
#        'Some Associated Projects', 'District', 'Country', 'Language', 'Topic',
#        'Topic.1', 'Topic.2', 'Topic.3', 'Topic.4', 'Notes'],
#       dtype='object')

# %%
SA_Groups["Sheet"]         = "Groups"
SA_Membership_req["Sheet"] = "Membership_req"
SA_Newsletters["Sheet"]    = "Newsletters"
# SA_working["Sheet]       = "working"

# %%
SA = SA_Groups.append(SA_Membership_req, ignore_index=True, verify_integrity=True)
SA = SA.append(SA_Newsletters,           ignore_index=True, verify_integrity=True)

# %%
SA.describe()
# Out:
#                                       URL                Name          Type  \
# count                                 145                 145           145
# unique                                142                 138            30
# top     https://github.com/data4democracy  Data For Democracy  Mailing List
# freq                                    2                   3            29
#
#                    Self-Description  \
# count                           139
# unique                          129
# top     Tech with humankind in mind
# freq                              6
#
#                                                   Purpose  \
# count                                                 142
# unique                                                126
# top     Promote the development of human centred projects
# freq                                                    7
#
#           Some Associated Projects District Country Language      Topic  \
# count                           19       42     135      145        140
# unique                          16       23      12        1         52
# top     http://www.involve.org.uk/   London      UK  English  Education
# freq                             3       17      86      145         10
#
#                Topic.1    Topic.2    Topic.3           Topic.4  \
# count              102         54         17                 3
# unique              49         33         12                 3
# top     Service Design  Democracy  Open Data  Internationalism
# freq                12          7          4                 1
#
#                   Notes   Sheet
# count                25     145
# unique               14       3
# top     In Person Event  Groups
# freq                  7     120

# %%
SA["Type"].value_counts()
# Out:
# Mailing List               29
# Meetup group               20
# Meetup Group               12
# Slack Team                 12
# Membership Portal          11
# Forum                       8
# Newsletter                  8
# Facebook Group (public)     5
# Facebook Group              5
# Mailing List                4
# Membership portal           4
# Facebook Group (Public)     3
# Slack Channel               3
# Facebook Group (closed)     3
# User Portal                 2
# Github Repository           2
# Facebook Group (Closed)     1
# Github repository           1
# Community Website           1
# Event page                  1
# Weekly Teleconference       1
# Google group                1
# Google Group                1
# Mailing List                1
# Mailing list                1
# Etherpad                    1
# Mailing List/Newsletter     1
# Wiki                        1
# Eventbrite Page             1
# Facebook page               1
# Name: Type, dtype: int64

# %%
SA["District"].value_counts()
# Out:
# London              17
# UK                   2
# Scotland             2
# South East           2
# Dublin               1
# Manchester           1
# Online               1
# NY                   1
# Global               1
# South West           1
# Birmingham           1
# Bristol              1
# based in USA         1
# USA                  1
# Cambridge            1
# Northern Ireland     1
# Wales                1
# Hackney              1
# Bath                 1
# Sheffield            1
# Midlands             1
# South                1
# Oxford               1
# Name: District, dtype: int64

# %%
SA["Country"].value_counts()
# Out:
# UK               86
# USA              20
# International     9
# Worldwide         5
# international     4
# worldwide         3
# EU                2
# UK/USA            2
# Ireland           1
# uk                1
# US                1
# Global            1
# Name: Country, dtype: int64

# %%
SA[["Topic","Topic.1","Topic.2","Topic.3","Topic.4"]].stack().value_counts()
# Out:
# Democracy                              21
# Technology                             18
# Open Data                              16
# Education                              12
# Civic Tech                             12
# Service Design                         12
# Journalism                             11
# Progressive                             9
# Government                              9
# Open Government                         8
# Activism                                8
# Local Government                        7
# Academia                                7
# Publishing                              6
# Third Sector                            6
# Co-ops                                  5
# Future of Work                          5
# Unions                                  5
# Digital Democracy                       4
# Health                                  4
# Transparency                            4
# Continuing Professional Development     4
# Diversity                               3
# Intermediate Technology                 3
# Data Visualisation                      3
# Public Engagement                       3
# Civic Technology                        3
# AI                                      3
# Open Source                             3
# open data                               3
#                                        ..
# Digital Urban Planning                  1
# Community                               1
# Local democracy                         1
# Open Charity                            1
# Investigation                           1
# Data Technology                         1
# Creative technology                     1
# Community Engagement                    1
# Data Journalism                         1
# Open Society                            1
# Sustainability                          1
# Parliamentary processes                 1
# Localism\n                              1
# Mobile                                  1
# Engineering                             1
# Corporates                              1
# d3.js                                   1
# technology                              1
# Research                                1
# News                                    1
# NewPolitics                             1
# Open Access                             1
# Media Activism                          1
# data security                           1
# Accountability                          1
# UK Parliament                           1
# Apps & Tools                            1
# Announcments                            1
# Data Privacy                            1
# Hackathons                              1
# Length: 113, dtype: int64

# %%
# avoid spurious differences in capitalisation by making these columns lower case
for col in ["Type","Country","Topic","Topic.1","Topic.2","Topic.3","Topic.4"]:
    print(col)
    non_null = SA[col].notnull()
    
    SA[col][non_null] =\
        SA[col][non_null].apply(lambda x: x.lower())
# Out:
# Type
# Country
# Topic
# Topic.1
# Topic.2
# Topic.3
# Topic.4

# %%
SA.describe()
# Out:
#                                       URL                Name          Type  \
# count                                 145                 145           145
# unique                                142                 138            23
# top     https://github.com/data4democracy  Data For Democracy  meetup group
# freq                                    2                   3            32
#
#                    Self-Description  \
# count                           139
# unique                          129
# top     Tech with humankind in mind
# freq                              6
#
#                                                   Purpose  \
# count                                                 142
# unique                                                126
# top     Promote the development of human centred projects
# freq                                                    7
#
#           Some Associated Projects District Country Language      Topic  \
# count                           19       42     135      145        140
# unique                          16       23       9        1         49
# top     http://www.involve.org.uk/   London      uk  English  open data
# freq                             3       17      87      145         11
#
#                Topic.1    Topic.2    Topic.3           Topic.4  \
# count              102         54         17                 3
# unique              45         33         12                 3
# top     service design  democracy  open data  internatlonalism
# freq                12          7          4                 1
#
#                   Notes   Sheet
# count                25     145
# unique               14       3
# top     In Person Event  Groups
# freq                  7     120

# %%
SA[["Topic","Topic.1","Topic.2","Topic.3","Topic.4"]].stack().value_counts()
# Out:
# democracy                              21
# open data                              19
# technology                             19
# education                              12
# journalism                             12
# civic tech                             12
# service design                         12
# government                              9
# progressive                             9
# open government                         8
# activism                                8
# academia                                7
# local government                        7
# publishing                              6
# third sector                            6
# unions                                  5
# future of work                          5
# continuing professional development     5
# co-ops                                  5
# digital democracy                       4
# data science                            4
# transparency                            4
# data visualisation                      4
# health                                  4
# wikimedia                               3
# diversity                               3
# open source                             3
# public engagement                       3
# surveillance                            3
# civic technology                        3
#                                        ..
# mobile                                  1
# data technology                         1
# community org                           1
# open charity                            1
# parliamentary processes                 1
# campaigning                             1
# data security                           1
# data collection/interpretation          1
# data/hacking                            1
# social justice                          1
# announcments                            1
# engineering                             1
# data journalism                         1
# open society                            1
# local representation                    1
# investigation                           1
# globalism                               1
# newpolitics                             1
# learn to code                           1
# media                                   1
# civil society                           1
# d3.js                                   1
# art                                     1
# society                                 1
# accountability                          1
# charities                               1
# economy                                 1
# community                               1
# electronic democracy                    1
# hackathons                              1
# Length: 104, dtype: int64

# %%
SA.columns = ['URL', 'Name', 'Type', 'Self-Description', 'Purpose',
       'Projects', 'District', 'Country', 'Language', 'Topic1',
       'Topic2', 'Topic3', 'Topic4', 'Topic5', 'Notes', 'Sheet']

# %%
SA
# Out:
#                                                    URL  \
# 0    https://groups.google.com/forum/#!forum/democr...
# 1                       http://democracyclub.slack.com
# 2       https://groups.google.com/forum/#!forum/poplus
# 3                  http://www.meetup.com/Journocoders/
# 4                 https://www.mysociety.org/subscribe/
# 5             http://groups.dowire.org/groups/exchange
# 6      https://www.facebook.com/groups/thefourthgroup/
# 7                  https://datafordemocracy.slack.com/
# 8                    https://github.com/data4democracy
# 9    https://pds.blog.parliament.uk/uk-parliament-d...
# 10                      https://meta-pol-is.slack.com/
# 11               https://representcommunity.slack.com/
# 12         https://www.meetup.com/Hackney-Hack-Nights/
# 13          https://www.meetup.com/HacksHackersLondon/
# 14   https://groups.google.com/forum/#!forum/influe...
# 15   https://www.ire.org/resource-center/listservs/...
# 16                       http://newsnerdery.org/ Slack
# 17                       https://dgroups.org/hivos/ogp
# 18   https://groups.google.com/forum/#!forum/pmo-ne...
# 19                              https://tinfoil.press/
# 20                              agamedevchat.slack.com
# 21   https://meta.wikimedia.org/wiki/Mailing_lists/...
# 22   https://lists.wikimedia.org/mailman/listinfo/w...
# 23   https://lists.mozilla.org/listinfo/community-mojo
# 24          https://opennews.org/what/community/calls/
# 25   https://groups.google.com/a/wikimedia.org/foru...
# 26   https://www.facebook.com/groups/nujournalists/...
# 27                  https://etherpad.net/p/dotcomrades
# 28        https://www.facebook.com/groups/workercoops/
# 29   https://www.facebook.com/groups/1170805349664629/
# ..                                                 ...
# 115                https://datafordemocracy.slack.com/
# 116  https://groups.google.com/forum/#!forum/openco...
# 117    https://lists.mozilla.org/listinfo/community-uk
# 118                 https://lists.mozilla.org/listinfo
# 119  https://groups.google.com/forum/#!forum/news-del2
# 120              https://www.computingatschool.org.uk/
# 121                          https://www.edutopia.org/
# 122                  https://digitalsocial.eu/register
# 123                        https://techsolidarity.org/
# 124                  https://www.techforcampaigns.org/
# 125                    https://civichall.org/civicist/
# 126                              https://super.global/
# 127  https://www.level-up.cc/community/community-re...
# 128                       http://localgovdigital.info/
# 129  http://localgovdigital.info/local-democracy-by...
# 130  http://localgovdigital.info/localgov-digital-m...
# 131  http://localgovdigital.info/localgov-digital-v...
# 132  http://localgovdigital.info/localgov-digital-v...
# 133                       http://digitalcharities.org/
# 134                                   http://ncdd.org/
# 135                     https://theodi.org/newsletters
# 136                        https://supporters.eff.org/
# 137                       http://www.wearecast.org.uk/
# 138  http://www.datakind.org/get-involved?type=data...
# 139  https://www.dashingd3js.com/data-visualization...
# 140      https://www.oreilly.com/feed/four-short-links
# 141              https://www.schneier.com/crypto-gram/
# 142              https://tinyletter.com/data-is-plural
# 143                       https://changelog.com/weekly
# 144     https://github.com/vredniy/awesome-newsletters
#
#                                                   Name  \
# 0                                       Democracy Club
# 1                                       Democracy Club
# 2                                               Poplus
# 3                                         Journocoders
# 4                                           My Society
# 5                          Democracies Online Exchange
# 6                                     The Fourth Group
# 7                                   Data For Democracy
# 8                                   Data For Democracy
# 9                      UK Parliament Data mailing list
# 10                       Pol.is platform experimenters
# 11                                 Represent Community
# 12             Hackney Hack Nights (Journalism & Tech)
# 13                                Hacks Hackers London
# 14                                   Influence Mapping
# 15                                           NICAR/IRE
# 16                                        News Nerdery
# 17                               OGB Civil Society Hub
# 18                                         PMO Network
# 19                                       Tinfoil press
# 20                                        AGameDevChat
# 21                                           Wiki*edia
# 22                                         WikimediaUK
# 23                                      Open News List
# 24                            Open News Community Call
# 25                                            WikiCite
# 26                           NUJ public facebook group
# 27                                         DotComrades
# 28                                Worker co-operatives
# 29                                       AI & Politics
# ..                                                 ...
# 115                           Data For Democracy slack
# 116                       Open Corporates Mailing List
# 117                                         Mozilla UK
# 118                                            Mozilla
# 119                                        [News-DEL2]
# 120                                Computing at School
# 121                                           Edutopia
# 122                          Digital Social Innovation
# 123                                    Tech Solidarity
# 124                                 Tech for Campaigns
# 125                                           Civicist
# 126                                       Super Global
# 127                                 Level-Up Community
# 128                                    LocalGovDigital
# 129                              Local Democracy Bites
# 130                                     LocalGovMakers
# 131                        LocalGovDigital Peer Groups
# 132                           LocalGovDigital Midlands
# 133                                  Digital Charities
# 134  National Coalition for Dialogue & Deliberation...
# 135                                Open Data Institute
# 136                     Electronic Frontier Foundation
# 137       Centre for Acceleration of Social Technology
# 138                                       Datakind UK
# 139       Data Visualization & D3.js Weekly Newsletter
# 140                                   Four Short Links
# 141                               Schneier on Security
# 142                                     Data is Plural
# 143                                   Changelog Weekly
# 144                                Awesome newsletters
#
#                         Type  \
# 0               mailing list
# 1                 slack team
# 2               mailing list
# 3               meetup group
# 4               mailing list
# 5                      forum
# 6             facebook group
# 7                 slack team
# 8          github repository
# 9               mailing list
# 10                slack team
# 11                slack team
# 12              meetup group
# 13              meetup group
# 14              mailing list
# 15              mailing list
# 16                slack team
# 17              mailing list
# 18              mailing list
# 19                     forum
# 20                slack team
# 21              mailing list
# 22              mailing list
# 23             mailing list
# 24     weekly teleconference
# 25              mailing list
# 26            facebook group
# 27                  etherpad
# 28            facebook group
# 29            facebook group
# ..                       ...
# 115               slack team
# 116             google group
# 117             mailing list
# 118             mailing list
# 119             google group
# 120        membership portal
# 121        membership portal
# 122        membership portal
# 123        membership portal
# 124        membership portal
# 125        membership portal
# 126        membership portal
# 127        membership portal
# 128        membership portal
# 129        membership portal
# 130        membership portal
# 131        membership portal
# 132        membership portal
# 133        membership portal
# 134        membership portal
# 135               newsletter
# 136               newsletter
# 137               newsletter
# 138  mailing list/newsletter
# 139               newsletter
# 140               newsletter
# 141               newsletter
# 142               newsletter
# 143               newsletter
# 144        github repository
#
#                                       Self-Description  \
# 0    Democracy Club aims to make the process of dem...
# 1    Democracy Club aims to make the process of dem...
# 2    A global federation for civic tech, sharing te...
# 3    Journocoders is a monthly event for exchanging...
# 4    We build and share digital technologies that g...
# 5    Join over 750 members on the two-way Democraci...
# 6    We are a group of people working together to c...
# 7    Like-minded people from around the world gathe...
# 8    Like-minded people from around the world gathe...
# 9         Mailing list to discuss UK parliament's data
# 10   meta-polis - Slack group for Pol.is platform e...
# 11   Community Channel for those building on repres...
# 12   A rolling hackathon for journalists, technolog...
# 13   This group aims to help members find inspirati...
# 14   Our goal is to share data-driven methods to ma...
# 15   Investigative Reporters and Editors, Inc. is a...
# 16   An international meta organization to foster n...
# 17   Welcome to the OGP civil society mailing list ...
# 18   An international network of civil society orga...
# 19   Tinfoil press; for journalism, media activism,...
# 20   Slack full of game developers. Email r.carboma...
# 21   These are the mailing lists hosted by Wikimedi...
# 22   This is a public mailing list for Wikimedians ...
# 23   This list is intended for discussion of the Kn...
# 24   The Source community calls are a community che...
# 25                                                 NaN
# 26   We are among the biggest and best-established ...
# 27   Workers of the world, swipe left! Using tech t...
# 28   A public UK and international group connecting...
# 29         Exploring the intersection of AI & politics
# ..                                                 ...
# 115  No structure. No rules. Just code commits and ...
# 116  OpenCorporates has a simple aim - to have a UR...
# 117  This is the mailing list for the Mozilla UK co...
# 118            All the public mailing lists on mozilla
# 119  Mailing list on research on electronic democra...
# 120  CAS is a community of individuals who are pass...
# 121  We emphasize core strategies: project-based le...
# 122  Showcase your project, meet collaborators, and...
# 123  Tech Solidarity is a grass-roots organization ...
# 124  We empower world-class tech talent to voluntee...
# 125                         Civic Tech News & Analysis
# 126  We are creative & tech agencies solving social...
# 127  This is LevelUp's repository of Community Reso...
# 128  LocalGov Digital is the network for digital pr...
# 129  Local Democracy Bytes is a workstream of Local...
# 130  Digital Makers is one of the 7 work streams of...
# 131  Our peer groups provide face-to-face and other...
# 132  The Midlands Peer Group, co-chaired by Coventr...
# 133  Digital Charities is a group of people working...
# 134  The National Coalition for Dialogue & Delibera...
# 135  There's always something exciting going on in ...
# 136  The Electronic Frontier Foundation is the lead...
# 137  We help funders, nonprofits, businesses and go...
# 138  Join thousands of data do-gooders, mission-dri...
# 139  Get D3.js and Data Visualization news, article...
# 140  Nat Torkington's eclectic collection of curate...
# 141  A security-focused monthly newsletter curated ...
# 142  A weekly newsletter of useful/curious datasets...
# 143  Every weekend we ship our editorialized take o...
# 144                      A list of amazing Newsletters
#
#                                                Purpose  \
# 0                         Crowdsource UK Election Data
# 1                         Crowdsource UK Election Data
# 2             Create open source civic tech components
# 3                            Teach journalists to code
# 4                                     Civic Engagement
# 5    Announce, source/make & discuss, democratic st...
# 6                        Civic Engagement, Campaigning
# 7                     Make digital tools for democracy
# 8                     Make digital tools for democracy
# 9             Connecting groups, building connections.
# 10   discussion route for those working on/with the...
# 11   discussion route for those working on/with rep...
# 12   The idea is that the Hackney Hackers will prov...
# 13   Talks and creating connections between Hacks (...
# 14   Community announcements and networking those w...
# 15   Mailing list and online resource centre for In...
# 16             Peer learning for technical journalists
# 17   List and archive access point for the OGP civi...
# 18        Mailing list and archive for the PMO network
# 19   Discussion space for journalism, activism, and...
# 20    Community connection, code review, collaboration
# 21       community connection, discussion, management,
# 22         Support those working on wiki*dia in the UK
# 23   Network Mozillians working on the Knight-Mozil...
# 24   Network Mozillians working on the Knight-Mozil...
# 25     Wikimedia list for the open citations community
# 26   Public facing facebook group to connect member...
# 27   Community engagement and recruitment for DotCo...
# 28   Network supporting recruitment to worker coope...
# 29   Discussion page for the AI & Politics communit...
# ..                                                 ...
# 115                   Make digital tools for democracy
# 116  Support & information for the OpenCorporates c...
# 117   Support and Information for Mozillians in the UK
# 118  To support and promote discussion amongst Mozi...
# 119  Information and support for those doing resear...
# 120  Community for Computing Science in Schools pro...
# 121  Information and Support for those teaching tec...
# 122  Networking for those interested in Digital Soc...
# 123  Promotion and discussion of Localised delivery...
# 124  Recruit and train volunteers for digital polit...
# 125  Support & information for US-based civic profe...
# 126                      Professional Services Network
# 127                Tools and information for Activists
# 128  Connect and support Digital practioners in UK ...
# 129  Connect and support Digital practioners in UK ...
# 130  Connect and support Digital practioners in UK ...
# 131  Connect and support Digital practioners in UK ...
# 132        Local Gov Digital Midlands Peer Group links
# 133  Networking and support for those working on di...
# 134    Information and Support for members of the NCDD
# 135  Announcements, Events publicity and calls for ...
# 136              Campaigns and fundraising for the EFF
# 137                                                NaN
# 138                                                NaN
# 139           Data visualisation tools and information
# 140  4 short links about (mostly research oriented)...
# 141    Provide collection of up to date security media
# 142  Collection and disemination of some open datasets
# 143  Newsletter covering the open source community ...
# 144                                                NaN
#
#                                               Projects      District  \
# 0    WhereDoIVote, WhoCanIVoteFor, Candidates, Elec...    South East
# 1    WhereDoIVote, WhoCanIVoteFor, Candidates, Elec...    South East
# 2    (WriteIt, Write and send messages to public fi...        Global
# 3                                                  NaN        London
# 4    FixMyStreet, WhatDoTheyKnow (freedom of inform...           NaN
# 5                                                  NaN           NaN
# 6                                                  NaN           NaN
# 7                                                  NaN           NaN
# 8    understanding the behavior of online communiti...           NaN
# 9                                                  NaN           NaN
# 10                                                 NaN           NaN
# 11                                        Represent.me           NaN
# 12   Hackney Hack Night on Care, Hackney Hack Night...       Hackney
# 13                                                 NaN        London
# 14                                                 NaN            UK
# 15                                                 NaN           USA
# 16                                       Oiler podcast           NaN
# 17                                 OGP Civil Society.             UK
# 18                                                 NaN           NaN
# 19                                                 NaN           NaN
# 20                                                 NaN           NaN
# 21   Wikipedia, Wiktionary, Wikibooks, Wikidata, Wi...  based in USA
# 22                                                 NaN           NaN
# 23                                                 NaN           NaN
# 24                                                 NaN           NaN
# 25                                                 NaN           NaN
# 26                                                 NaN           NaN
# 27                                                 NaN           NaN
# 28                                                 NaN           NaN
# 29                                                 NaN           NaN
# ..                                                 ...           ...
# 115                                                NaN           NaN
# 116                                                NaN           NaN
# 117                                                NaN           NaN
# 118                                                NaN           NaN
# 119                                                NaN           NaN
# 120                                                NaN           NaN
# 121    Part of the George Lucas Educational Foundation           NaN
# 122                                                NaN           NaN
# 123                                                NaN           NaN
# 124                                                NaN           NaN
# 125                                                NaN            NY
# 126                                                NaN           NaN
# 127                                                NaN           NaN
# 128  Unmentoring, Local Democracy Bytes, Local Gove...           NaN
# 129                                                NaN           NaN
# 130                                                NaN           NaN
# 131                LocalGovCamp Unconference, teacamp,           NaN
# 132                                                NaN      Midlands
# 133                                                NaN           NaN
# 134                                                NaN           NaN
# 135                                                NaN           NaN
# 136                                                NaN           NaN
# 137                                               lots           NaN
# 138                                                NaN           NaN
# 139                                                NaN           NaN
# 140                                                NaN           NaN
# 141                                                NaN           NaN
# 142                                                NaN           NaN
# 143                                                NaN           NaN
# 144                                                NaN           NaN
#
#            Country Language                          Topic1  \
# 0               uk  English                      civic tech
# 1               uk  English                      civic tech
# 2           global  English                      civic tech
# 3               uk  English                      journalism
# 4               uk  English                       democracy
# 5               uk  English                     campaigning
# 6               uk  English                     newpolitics
# 7              NaN  English               digital democracy
# 8               us  English  data collection/interpretation
# 9               uk  English                       open data
# 10             NaN  English               digital democracy
# 11              uk  English                       open data
# 12              uk  English                       community
# 13              uk  English                      journalism
# 14              uk  English                       economics
# 15             usa  English                      journalism
# 16       worldwide  English                            news
# 17              uk  English               public engagement
# 18       worldwide  English         parliamentary processes
# 19             NaN  English                crypto education
# 20             NaN  English                           games
# 21             usa  English                       wikimedia
# 22              uk  English                      journalism
# 23   international  English                      journalism
# 24             usa  English                      journalism
# 25             NaN  English                      journalism
# 26              uk  English                      journalism
# 27              uk  English                          unions
# 28              uk  English                          unions
# 29              uk  English                          unions
# ..             ...      ...                             ...
# 115         uk/usa  English                       democracy
# 116             uk  English                  corporate data
# 117             uk  English                       education
# 118  international  English                       education
# 119            usa  English            electronic democracy
# 120             uk  English                       education
# 121            usa  English                       education
# 122             eu  English                    third sector
# 123            usa  English                     progressive
# 124            usa  English                     progressive
# 125            usa  English                      civic tech
# 126             uk  English                             NaN
# 127            usa  English                             NaN
# 128             uk  English                      government
# 129             uk  English                      government
# 130             uk  English                local government
# 131             uk  English                local government
# 132             uk  English                local government
# 133             uk  English                    third sector
# 134            usa  English                      innovation
# 135             uk  English                       open data
# 136            usa  English                         privacy
# 137             uk  English                             NaN
# 138             uk  English                              ai
# 139      worldwide  English              data visualisation
# 140            usa  English             coding for research
# 141            usa  English                       open data
# 142            usa  English                       open data
# 143  international  English                       open data
# 144            NaN  English                civic technology
#
#                                   Topic2                Topic3  \
# 0                              elections             democracy
# 1                              elections             democracy
# 2                                    NaN                   NaN
# 3                          learn to code                   NaN
# 4                             civic tech                   foi
# 5                              democracy          announcments
# 6                              democracy  community organising
# 7                              open data             democracy
# 8                              democracy         community org
# 9                          uk parliament             democracy
# 10                             democracy                   NaN
# 11                     digital democracy             democracy
# 12                          apps & tools       local democracy
# 13                            technology       open technology
# 14                              politics            corporates
# 15                              politics         investigation
# 16                            technology          data/hacking
# 17                         civil society             democracy
# 18                                   NaN                   NaN
# 19                          data privacy            journalism
# 20                                   NaN                   NaN
# 21                            journalism            publishing
# 22                            publishing                   NaN
# 23                            publishing                   NaN
# 24                            publishing                   NaN
# 25                            publishing                   NaN
# 26                           trade union            publishing
# 27                                co-ops        future of work
# 28                                co-ops        future of work
# 29                                co-ops        future of work
# ..                                   ...                   ...
# 115                            open data    data visualisation
# 116                       accountability                   NaN
# 117                          open source                   NaN
# 118                          open source                   NaN
# 119                         open society                   NaN
# 120  continuing professional development                   NaN
# 121  continuing professional development                   NaN
# 122                             activism                   NaN
# 123                                  NaN                   NaN
# 124                                  NaN                   NaN
# 125                                  NaN                   NaN
# 126                                  NaN                   NaN
# 127                                  NaN                   NaN
# 128                       service design                   NaN
# 129                       service design             democracy
# 130                       service design                   NaN
# 131                       service design                   NaN
# 132                       service design                   NaN
# 133                             activism                   NaN
# 134                            democracy             education
# 135                                  NaN                   NaN
# 136                         surveillance              activism
# 137                                  NaN                   NaN
# 138                         data science                   NaN
# 139                                d3.js                   NaN
# 140                         data science            web design
# 141                         data science         data security
# 142                   data visualisation                   NaN
# 143                          open source                   NaN
# 144                                  NaN                   NaN
#
#                    Topic4                  Topic5  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# 5                academia        internationalism
# 6              technology                     NaN
# 7                     NaN                     NaN
# 8              technology        internatlonalism
# 9       digital democracy                     NaN
# 10                    NaN                     NaN
# 11                    NaN                     NaN
# 12   local representation  digital urban planning
# 13        data technology                     NaN
# 14             journalism                     NaN
# 15                    NaN                     NaN
# 16                    NaN                     NaN
# 17              economics                     NaN
# 18                    NaN                     NaN
# 19         media activism                     NaN
# 20                    NaN                     NaN
# 21                    NaN                     NaN
# 22                    NaN                     NaN
# 23                    NaN                     NaN
# 24                    NaN                     NaN
# 25                    NaN                     NaN
# 26                    NaN                     NaN
# 27                    NaN                     NaN
# 28                    NaN                     NaN
# 29                    NaN                     NaN
# ..                    ...                     ...
# 115                   NaN                     NaN
# 116                   NaN                     NaN
# 117                   NaN                     NaN
# 118                   NaN                     NaN
# 119                   NaN                     NaN
# 120                   NaN                     NaN
# 121                   NaN                     NaN
# 122                   NaN                     NaN
# 123                   NaN                     NaN
# 124                   NaN                     NaN
# 125                   NaN                     NaN
# 126                   NaN                     NaN
# 127                   NaN                     NaN
# 128                   NaN                     NaN
# 129                   NaN                     NaN
# 130                   NaN                     NaN
# 131                   NaN                     NaN
# 132                   NaN                     NaN
# 133                   NaN                     NaN
# 134                   NaN                     NaN
# 135                   NaN                     NaN
# 136                   NaN                     NaN
# 137                   NaN                     NaN
# 138                   NaN                     NaN
# 139                   NaN                     NaN
# 140       online security                     NaN
# 141       online security                     NaN
# 142                   NaN                     NaN
# 143                   NaN                     NaN
# 144                   NaN                     NaN
#
#                                                  Notes           Sheet
# 0                                                  NaN          Groups
# 1                                                  NaN          Groups
# 2                                                  NaN          Groups
# 3                                      In Person Event          Groups
# 4                                                  NaN          Groups
# 5                                                  NaN          Groups
# 6                                                  NaN          Groups
# 7                                                  NaN          Groups
# 8                                                  NaN          Groups
# 9                                                  NaN          Groups
# 10                                                 NaN          Groups
# 11                                                 NaN          Groups
# 12                                     In Person Event          Groups
# 13                                     In Person Event          Groups
# 14                                                 NaN          Groups
# 15                                                 NaN          Groups
# 16                                                 NaN          Groups
# 17                                                 NaN          Groups
# 18   Worldwide in this case is very focused on the ...          Groups
# 19   Completely open list - advocates for encryptio...          Groups
# 20   Email r.carbomascarell@gmail.com to get an invite          Groups
# 21                                                 NaN          Groups
# 22                                                 NaN          Groups
# 23                                                 NaN          Groups
# 24                                                 NaN          Groups
# 25                                                 NaN          Groups
# 26                                                 NaN          Groups
# 27                                                 NaN          Groups
# 28                                                 NaN          Groups
# 29                                                 NaN          Groups
# ..                                                 ...             ...
# 115  https://medium.com/data-for-democracy/the-firs...          Groups
# 116                        https://opencorporates.com/          Groups
# 117                                                NaN          Groups
# 118                                                NaN          Groups
# 119                                                NaN          Groups
# 120                                                NaN  Membership_req
# 121                                                NaN  Membership_req
# 122                                                NaN  Membership_req
# 123                                                NaN  Membership_req
# 124                                                NaN  Membership_req
# 125                                                NaN  Membership_req
# 126                                                NaN  Membership_req
# 127                                                NaN  Membership_req
# 128                                            Network  Membership_req
# 129                                                NaN  Membership_req
# 130  Newsletter is on http://localgovdigital.info/l...  Membership_req
# 131                                                NaN  Membership_req
# 132             midlandspeergroup@localgovdigital.info  Membership_req
# 133                                                NaN  Membership_req
# 134                                                NaN  Membership_req
# 135                                                NaN     Newsletters
# 136                                                NaN     Newsletters
# 137                                                NaN     Newsletters
# 138                                                NaN     Newsletters
# 139                                                NaN     Newsletters
# 140                                                NaN     Newsletters
# 141                                                NaN     Newsletters
# 142                                                NaN     Newsletters
# 143                                                NaN     Newsletters
# 144  Pulled out a few obvious ones, wrt political t...     Newsletters
#
# [145 rows x 16 columns]

# %%
# Merge topics (into comma separated list)
SA["Topics"] = \
    SA[['Topic1','Topic2', 'Topic3', 'Topic4', 'Topic5']]\
    .apply( lambda x: x.str.cat(sep=','), axis=1)

# %%
# Drop redundant columns
SA = SA.drop(['Topic1','Topic2', 'Topic3', 'Topic4', 'Topic5'],axis=1)

# %%
# reorder columns
SA = SA[ ['URL', 'Name',
 'Sheet', 'Type',
 'Self-Description', 'Purpose',
 'Topics',
 'Projects',
 'Language', 'Country', 'District',
 'Notes' ] ]

# %%
# maybe we should include the key for now?
SA.to_csv(SA_data_folder+"Newspeak House Unmailing List - processed.csv", index=False)

# %%
# Airtable Setup Notes

# * important csv
# * update name "Newspeak House Unmailing List"
# * convert Sheet & Type to Single Select
# * convert Topics to Multiple Select
# * convert Self-Description, Purpose to Long Text
